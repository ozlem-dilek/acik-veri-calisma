# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("ilce-mahalle-bazli-hayvan-beslemede-kullanilan-urunler-veri.csv")

# %%
pd.options.display.max_rows = None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   _id                                  773 non-null    int64
#  1   ilce_adi                             772 non-null    object
#  2   mahalle_adi                          772 non-null    object
#  3   hayvan_beslemede_kullanilan_urunler  770 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 24.3+ KB

# %%
data.head()
# Out:
#    _id ilce_adi mahalle_adi  hayvan_beslemede_kullanilan_urunler
# 0    1   Ahırlı    ALİÇERÇİ                      ARPA, HAZIR YEM
# 1    2   Ahırlı     BADEMLİ     KÜSPE, SİLAJLIK MISIR, HAZIR YEM
# 2    3   Ahırlı   BALIKLAVA  KÜSPE, ARPA, ÇAVDAR, SİLAJLIK MISIR
# 3    4   Ahırlı     BÜYÜKÖZ           BUĞDAY, KÜSPE, KEPEK, ARPA
# 4    5   Ahırlı     ÇİFTLİK       BUĞDAY, ARPA, SAMAN, HAZIR YEM

# %%
data.drop(index=772, inplace=True)

# %%
data.drop(columns="_id", inplace=True)

# %%
data.tail()
# Out:
#     ilce_adi mahalle_adi        hayvan_beslemede_kullanilan_urunler
# 767    Yunak     YAVAŞLI                    SAMAN, YONCA, HAZIR YEM
# 768    Yunak    YEŞİLOBA     YULAF, ARPA, SİLAJLIK MISIR, HAZIR YEM
# 769    Yunak  YEŞİLYAYLA      BUĞDAY, KÜSPE, ARPA, SAMAN, HAZIR YEM
# 770    Yunak       YIĞAR  BUĞDAY, FİĞ, SAMAN, YONCA, SİLAJLIK MISIR
# 771    Yunak       SARAY                        FİĞ, SİLAJLIK MISIR

# %%
for i in range(0,772):
    if data["hayvan_beslemede_kullanilan_urunler"][i] == "None":
        print(f"{i}. indexte")

# %%
data["veri_sayisi"] = data["hayvan_beslemede_kullanilan_urunler"].str.count(",") + 1

# %%
data["veri_sayisi"].max()
# Out:
# 7.0

# %%
data["hayvan_beslemede_kullanilan_urunler"] = data["hayvan_beslemede_kullanilan_urunler"].astype(str)

# %%
data[["hayvan_beslemede_kullanilan_urunler1","hayvan_beslemede_kullanilan_urunler2", "hayvan_beslemede_kullanilan_urunler3", "hayvan_beslemede_kullanilan_urunler4", "hayvan_beslemede_kullanilan_urunler5", "hayvan_beslemede_kullanilan_urunler6", "hayvan_beslemede_kullanilan_urunler7"]] = data["hayvan_beslemede_kullanilan_urunler"].str.split(",", expand=True)

# %%
data.drop(columns="veri_sayisi", inplace=True)

# %%
data.drop(columns="hayvan_beslemede_kullanilan_urunler", inplace=True)

# %%
for index, row in data.iterrows():
    for col in data.columns:
        if pd.isnull(row[col]):
            data.loc[index, col] = "YOK"

# %%
data.drop(index=676, inplace=True)
data.drop(index=644, inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#        ilce_adi       mahalle_adi hayvan_beslemede_kullanilan_urunler1  \
# 0        Ahırlı          ALİÇERÇİ                                 ARPA
# 1        Ahırlı           BADEMLİ                                KÜSPE
# 2        Ahırlı         BALIKLAVA                                KÜSPE
# 3        Ahırlı           BÜYÜKÖZ                               BUĞDAY
# 4        Ahırlı           ÇİFTLİK                               BUĞDAY
# 5        Ahırlı           ERDOĞAN                                  FİĞ
# 6        Ahırlı        KARACAKUYU                                SAMAN
# 7        Ahırlı           KAYACIK                                  FİĞ
# 8        Ahırlı           KURUÇAY                                 ARPA
# 9        Ahırlı           KÜÇÜKÖZ                                KÜSPE
# 10       Akören             AVDAN                            HAZIR YEM
# 11       Akören            KAYASU                                 ARPA
# ...

# %%
data.to_csv("/Users/o/Desktop/acik-veri-calismalari/ilce-mahalle-bazli-hayvan-beslemede-kullanilan-urunler/ilce-mahalle-bazli-hayvan-beslemede-kullanilan-urunler.csv", index=False, header=True)
data.to_excel("/Users/o/Desktop/acik-veri-calismalari/ilce-mahalle-bazli-hayvan-beslemede-kullanilan-urunler/ilce-mahalle-bazli-hayvan-beslemede-kullanilan-urunler.xlsx", index=False, header=True)
