# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("bakiye-yukleme-sayilari-2019-verileri.csv")

# %%
pd.options.display.max_rows=None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8493 entries, 0 to 8492
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         8493 non-null   int64
#  1   tarih                       8493 non-null   object
#  2   saat                        8493 non-null   int64
#  3   bakiye_yukleme_adedi        8493 non-null   int64
#  4   bakiye_yuklenen_kart_adedi  8493 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 331.9+ KB

# %%
data.head(300)
# Out:
#      _id                tarih  saat  bakiye_yukleme_adedi  \
# 0      1  2019-01-01T00:00:00     0                    67
# 1      2  2019-01-01T00:00:00     1                    10
# 2      3  2019-01-01T00:00:00     2                     1
# 3      4  2019-01-01T00:00:00     3                     3
# 4      5  2019-01-01T00:00:00     4                     1
# 5      6  2019-01-01T00:00:00     5                     6
# 6      7  2019-01-01T00:00:00     6                    28
# 7      8  2019-01-01T00:00:00     7                   481
# 8      9  2019-01-01T00:00:00     8                   658
# 9     10  2019-01-01T00:00:00     9                   772
# 10    11  2019-01-01T00:00:00    10                  1017
# 11    12  2019-01-01T00:00:00    11                  1687
# 12    13  2019-01-01T00:00:00    12                  2078
# 13    14  2019-01-01T00:00:00    13                  2090
# 14    15  2019-01-01T00:00:00    14                  2162
# ...
