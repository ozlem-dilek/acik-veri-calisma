# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = None

# %%
data = pd.read_csv("bakiye-yukleme-sayilari-verileri-2021.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3508 entries, 0 to 3507
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         3508 non-null   int64
#  1   tarih                       3508 non-null   object
#  2   saat                        3508 non-null   int64
#  3   bakiye_yukleme_adedi        3508 non-null   int64
#  4   bakiye_yuklenen_kart_adedi  3508 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 137.2+ KB

# %%
data.head(500)
# Out:
#      _id                tarih  saat  bakiye_yukleme_adedi  \
# 0      1  2021-01-01T00:00:00     1                     1
# 1      2  2021-01-01T00:00:00     4                     1
# 2      3  2021-01-01T00:00:00     7                    27
# 3      4  2021-01-01T00:00:00     8                    19
# 4      5  2021-01-01T00:00:00     9                    24
# 5      6  2021-01-01T00:00:00    10                    51
# 6      7  2021-01-01T00:00:00    11                    56
# 7      8  2021-01-01T00:00:00    12                    38
# 8      9  2021-01-01T00:00:00    13                   132
# 9     10  2021-01-01T00:00:00    14                   122
# 10    11  2021-01-01T00:00:00    15                   127
# 11    12  2021-01-01T00:00:00    16                   145
# 12    13  2021-01-01T00:00:00    17                    51
# 13    14  2021-01-01T00:00:00    18                    33
# 14    15  2021-01-01T00:00:00    19                    16
# ...
