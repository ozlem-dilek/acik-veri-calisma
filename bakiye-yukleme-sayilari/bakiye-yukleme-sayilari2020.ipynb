# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = None

# %%
data = pd.read_csv("bakiye-yukleme-sayilari-verileri-2020.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728 entries, 0 to 7727
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         7728 non-null   int64
#  1   tarih                       7728 non-null   object
#  2   saat                        7728 non-null   int64
#  3   bakiye_yukleme_adedi        7728 non-null   int64
#  4   bakiye_yuklenen_kart_adedi  7728 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 302.0+ KB

# %%
data.head(750)
# Out:
#      _id                tarih  saat  bakiye_yukleme_adedi  \
# 0      1  2020-01-01T00:00:00     0                    74
# 1      2  2020-01-01T00:00:00     1                    12
# 2      3  2020-01-01T00:00:00     2                     4
# 3      4  2020-01-01T00:00:00     3                     2
# 4      5  2020-01-01T00:00:00     5                     3
# 5      6  2020-01-01T00:00:00     6                    30
# 6      7  2020-01-01T00:00:00     7                   584
# 7      8  2020-01-01T00:00:00     8                   783
# 8      9  2020-01-01T00:00:00     9                   832
# 9     10  2020-01-01T00:00:00    10                  1181
# 10    11  2020-01-01T00:00:00    11                  1739
# 11    12  2020-01-01T00:00:00    12                  2281
# 12    13  2020-01-01T00:00:00    13                  2283
# 13    14  2020-01-01T00:00:00    14                  2289
# 14    15  2020-01-01T00:00:00    15                  2297
# ...
