# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("elkart-toplam-yukleme-sayilari-2019.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8506 entries, 0 to 8505
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tarih_saat                  8506 non-null   object
#  1   yukleme_adedi               8506 non-null   int64
#  2   yukleme_yapilan_kart_adedi  8506 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 199.5+ KB

# %%
pd.options.display.max_rows = None

# %%
data.head(500)
# Out:
#               tarih_saat  yukleme_adedi  yukleme_yapilan_kart_adedi
# 0    2019-01-01 00:00:00             67                          65
# 1    2019-01-01 01:00:00             10                           9
# 2    2019-01-01 02:00:00              1                           1
# 3    2019-01-01 03:00:00              3                           3
# 4    2019-01-01 04:00:00              1                           1
# 5    2019-01-01 05:00:00              6                           6
# 6    2019-01-01 06:00:00             28                          28
# 7    2019-01-01 07:00:00            493                         488
# 8    2019-01-01 08:00:00            676                         670
# 9    2019-01-01 09:00:00            776                         766
# 10   2019-01-01 10:00:00           1026                        1015
# 11   2019-01-01 11:00:00           1699                        1676
# 12   2019-01-01 12:00:00           2094                        2062
# ...
