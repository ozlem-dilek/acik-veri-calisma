# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = None

# %%
data = pd.read_csv("aykome-kazi-ruhsat-veriler-temizlenmemis.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            156 non-null    int64
#  1   donem          156 non-null    object
#  2   ruhsat_sayisi  156 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.8+ KB

# %%
data.head()
# Out:
#    _id                donem  ruhsat_sayisi
# 0    1  2008-04-01T00:00:00            241
# 1    2  2009-01-01T00:00:00            285
# 2    3  2009-05-01T00:00:00            649
# 3    4  2012-01-01T00:00:00             51
# 4    5  2009-10-01T00:00:00            476

# %%
data.drop(columns= "_id", axis=0, inplace=True)

# %%
data["donem"] = pd.to_datetime(data["donem"])

# %%
data.sort_values(by="donem", inplace=True)

# %%
data.rename(columns={"donem" : "baslangic_tarihi"}, inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data["baslangic_tarihi"] = data["baslangic_tarihi"].astype(str)

# %%
type(data["baslangic_tarihi"][0])
# Out:
# str

# %%
data["bitis_tarihi"] = data["baslangic_tarihi"].copy()

# %%
for index in range(0,156):
    if data["bitis_tarihi"][index][5:7] == "01":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "03":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "04":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "05":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "06":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "07":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "08":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "09":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "10":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "11":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "12":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "02":
        if data["bitis_tarihi"][index][:4] == "2008":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
        elif data["bitis_tarihi"][index][:4] == "2009":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2010":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2011":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2012":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
        elif data["bitis_tarihi"][index][:4] == "2013":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2014":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2015":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2016":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
        elif data["bitis_tarihi"][index][:4] == "2017":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2018":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2019":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2020":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
        elif data["bitis_tarihi"][index][:4] == "2021":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_47204/2218044662.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"

# %%
yeni_sutunlar = ["baslangic_tarihi", "bitis_tarihi", "ruhsat_sayisi"]

# %%
data = data[yeni_sutunlar]

# %%
data["baslangic_tarihi"] = pd.to_datetime(data["baslangic_tarihi"], format = "%Y-%m-%d")

# %%
data["bitis_tarihi"] = pd.to_datetime(data["bitis_tarihi"], format = "%Y-%m-%d")

# %%
data
# Out:
#     baslangic_tarihi bitis_tarihi  ruhsat_sayisi
# 0         2008-04-01   2008-04-30            241
# 1         2008-05-01   2008-05-31            519
# 2         2008-06-01   2008-06-30            638
# 3         2008-07-01   2008-07-31            685
# 4         2008-08-01   2008-08-31            400
# 5         2008-09-01   2008-09-30            487
# 6         2008-10-01   2008-10-31            505
# 7         2008-11-01   2008-11-30            222
# 8         2008-12-01   2008-12-31             56
# 9         2009-01-01   2009-01-31            285
# 10        2009-02-01   2009-02-28            411
