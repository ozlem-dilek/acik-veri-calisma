# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("ucretsiz-wifi-nok.csv")

# %%
pd.options.display.max_rows = None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   _id                          80 non-null     int64
#  1   no                           80 non-null     int64
#  2   ucretsiz_wifi_noktalari_adi  80 non-null     object
#  3   1.erisim_koordinat           80 non-null     object
#  4   2._erisim_koordinat          4 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 3.3+ KB

# %%
data.head(50)
# Out:
#     _id  no             ucretsiz_wifi_noktalari_adi  \
# 0     1   1                         Eski SGK Binası
# 1     2   2     Başkanlık Özel Kalem (Alman Evleri)
# 2     3   3                        Elkart Müdürlüğü
# 3     4   4             Fen İşleri Daire Başkanlığı
# 4     5   5                     Millet Kıraathanesi
# 5     6   6      İrfan Medeniyeti Araştırma Merkezi
# 6     7   7                       KültürPark Zabıta
# 7     8   8                    Mezar Taşları Müzesi
# 8     9   9                  Mevlana Kültür Merkezi
# 9    10  10  Park Bahçe Daire Başkanlığı İdari Bina
# 10   11  11           Raylı Sistem Daire Başkanlığı
# 11   12  12                      Tarımsal Hizmetler
# 12   13  13                      Tatlıcak Tesisleri
# 13   14  14                        Aydınlık İtfaiye
# 14   15  15                           Hayvan Pazarı
# 15   16  16                        Kültürpark Kadem
# 16   17  17             Kılıçarslan Toplantı Salonu
# ...

# %%
data.drop(columns="_id", axis=0, inplace=True)
data.drop(columns="no", axis=0, inplace=True)
data.drop(columns="2._erisim_koordinat", axis=0, inplace= True)

# %%
data["1.erisim_koordinat"][2]
# Out:
# '37.873734, 32.487142'

# %%
data[["enlem", "boylam"]] = data["1.erisim_koordinat"].astype(str).str.split(", ", expand=True)

# %%
data.drop(columns="1.erisim_koordinat", axis=0,  inplace=True)

# %%
data.head()
# Out:
#            ucretsiz_wifi_noktalari_adi      enlem     boylam
# 0                      Eski SGK Binası  37.870055  32.482229
# 1  Başkanlık Özel Kalem (Alman Evleri)  37.869196  32.477103
# 2                     Elkart Müdürlüğü  37.873734  32.487142
# 3          Fen İşleri Daire Başkanlığı  37.937266  32.512032
# 4                  Millet Kıraathanesi  37.874856  32.489072

# %%
data.to_csv("/Users/o/Desktop/staj/orta seviye veriler/ucretsiz-wifi-erisim-noktalari/ucretsiz-wifi-erisim-noktalari.csv")
data.to_excel("/Users/o/Desktop/staj/orta seviye veriler/ucretsiz-wifi-erisim-noktalari/ucretsiz-wifi-erisim-noktalari.xlsx")
