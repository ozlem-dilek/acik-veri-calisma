# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("ilce-mahalle-bazli-iyi-tarim-uygulamalari-veri.csv")

# %%
pd.options.display.max_rows = None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     773 non-null    int64
#  1   ilce_adi                772 non-null    object
#  2   mahalle_adi             772 non-null    object
#  3   iyi_tarim_uygulamalari  769 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 24.3+ KB

# %%
data.tail()
# Out:
#      _id ilce_adi mahalle_adi iyi_tarim_uygulamalari
# 768  769    Yunak    YEŞİLOBA                   EVET
# 769  770    Yunak  YEŞİLYAYLA                   EVET
# 770  771    Yunak       YIĞAR                  HAYIR
# 771  772    Yunak       SARAY                  HAYIR
# 772  773      NaN         NaN                    NaN

# %%
data.drop(columns="_id", inplace=True)

# %%
data.drop(index=772, inplace=True)
data.drop(index=676, inplace=True)
data.drop(index=644, inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
for index, row in data.iterrows():
    for col in data.columns:
        if (row[col]) == "EVET":
            data.loc[index, col] = "VAR"
        elif (row[col]) == "HAYIR":
            data.loc[index, col] = "YOK"

# %%
data
# Out:
#        ilce_adi       mahalle_adi iyi_tarim_uygulamalari
# 0        Ahırlı          ALİÇERÇİ                    YOK
# 1        Ahırlı           BADEMLİ                    YOK
# 2        Ahırlı         BALIKLAVA                    YOK
# 3        Ahırlı           BÜYÜKÖZ                    YOK
# 4        Ahırlı           ÇİFTLİK                    YOK
# 5        Ahırlı           ERDOĞAN                    VAR
# 6        Ahırlı        KARACAKUYU                    YOK
# 7        Ahırlı           KAYACIK                    YOK
# 8        Ahırlı           KURUÇAY                    YOK
# 9        Ahırlı           KÜÇÜKÖZ                    YOK
# 10       Akören             AVDAN                    YOK
# 11       Akören            KAYASU                    YOK
# 12       Akören          AHMEDİYE                    YOK
# 13       Akören              ALAN                    YOK
# 14       Akören           BELKUYU                    YOK
# ...

# %%
data.to_csv("/Users/o/Desktop/acik-veri-calismalari/ilce-mahalle-bazli-iyi-tarim-uygulamalari/ilce-mahalle-bazli-iyi-tarim-uygulamalari.csv", index=False, header=True)
data.to_excel("/Users/o/Desktop/acik-veri-calismalari/ilce-mahalle-bazli-iyi-tarim-uygulamalari/ilce-mahalle-bazli-iyi-tarim-uygulamalari.xlsx", index=False, header=True)
