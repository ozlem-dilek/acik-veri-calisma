# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("hal-fiyatlari-temizlenmemis-veri.csv", sep= ";")

# %%
pd.options.display.max_columns = None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 94 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tarih                    188 non-null    object
#  1   sogan_yesil_(yerli)      188 non-null    float64
#  2   turp_kirmizi_(yerli)     188 non-null    float64
#  3   semiz_otu(bag)_yerli     187 non-null    float64
#  4   armut_(yerli)            187 non-null    float64
#  5   biber_carli_(yerli)      187 non-null    float64
#  6   maydonoz_(yerli)_bag     187 non-null    float64
#  7   kiraz_(yerli)            187 non-null    float64
#  8   biber_kÄ±l_(yerli)       187 non-null    float64
#  9   havuc                    187 non-null    float64
#  10  visne_(yerli)            187 non-null    float64
#  11  biber_sivri_(yerli)      187 non-null    float64
#  12  salatalik_(yerli)        186 non-null    float64
# ...

# %%
data.head()
# Out:
#         tarih  sogan_yesil_(yerli)  turp_kirmizi_(yerli)  \
# 0  24.06.2021                  0.5                   9.0
# 1  21.06.2021                  0.5                   9.0
# 2  14.06.2021                  2.0                   2.5
# 3  10.06.2021                  2.0                   1.0
# 4   7.06.2021                  2.0                   1.0
#
#    semiz_otu(bag)_yerli  armut_(yerli)  biber_carli_(yerli)  \
# 0                   2.0            1.5                  2.5
# 1                   2.0            2.0                  1.5
# 2                   1.0            2.5                  1.5
# 3                   2.5            1.5                  1.0
# 4                   2.5            1.5                  1.0
#
#    maydonoz_(yerli)_bag  kiraz_(yerli)  biber_kÄ±l_(yerli)  havuc  \
# 0                   1.0            2.5                 1.5    1.0
# 1                   2.5            1.0                 2.5    1.5
# ...

# %%
data["tarih"] = data["tarih"].astype(str).str.replace(".", "-")
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_9342/1187946978.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["tarih"] = data["tarih"].astype(str).str.replace(".", "-")

# %%
data["tarih"] = pd.to_datetime(data["tarih"], format='%d-%m-%Y')

# %%
data
# Out:
#          tarih  sogan_yesil_(yerli)  turp_kirmizi_(yerli)  \
# 0   2021-06-24                  0.5                   9.0
# 1   2021-06-21                  0.5                   9.0
# 2   2021-06-14                  2.0                   2.5
# 3   2021-06-10                  2.0                   1.0
# 4   2021-06-07                  2.0                   1.0
# ..         ...                  ...                   ...
# 183 2019-08-15                  0.3                   4.0
# 184 2019-08-08                  0.3                   4.0
# 185 2019-08-05                  0.3                   3.0
# 186 2019-08-01                  0.3                   3.0
# 187 2019-07-29                  0.3                   3.0
#
#      semiz_otu(bag)_yerli  armut_(yerli)  biber_carli_(yerli)  \
# 0                     2.0            1.5                  2.5
# 1                     2.0            2.0                  1.5
# 2                     1.0            2.5                  1.5
# ...

# %%
data.to_csv("/Users/o/Desktop/staj/orta seviye veriler/hal-fiyatlari/hal-fiyatlari.csv")
data.to_excel("/Users/o/Desktop/staj/orta seviye veriler/hal-fiyatlari/hal-fiyatlari.xlsx")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data.to_csv("/Users/o/Desktop/staj/orta seviye veriler/hal-fiyatlari/hal-fiyatlari.csv")
#       2 data.to_excel("/Users/o/Desktop/staj/orta seviye veriler/hal-fiyatlari/hal-fiyatlari.xlsx")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
# ...
