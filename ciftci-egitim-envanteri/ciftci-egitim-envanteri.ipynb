# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("ciftci-egitim-envanteri-veri.csv", sep = ";")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   s.no                                  31 non-null     float64
#  1   ilcesi                                31 non-null     object
#  2   2015_egitim_verilen_mahalle_sayisi    31 non-null     float64
#  3   2015_kursiyer_sayisi                  31 non-null     float64
#  4   2016_egitim_verilen_mahalle_sayisi    31 non-null     float64
#  5   2016_kursiyer_sayisi                  31 non-null     float64
#  6   2017_egitim_verilen_mahalle_sayisi    31 non-null     float64
#  7   2017_kursiyer_sayisi                  31 non-null     float64
#  8   2018_egitim_verilen_mahalle_sayisi    31 non-null     float64
#  9   2018_kursiyer_sayisi                  31 non-null     float64
# ...

# %%
data
# Out:
#         ilcesi  2015_egitim_verilen_mahalle_sayisi  2015_kursiyer_sayisi  \
# 0       AHIRLI                                  10                   973
# 1       AKÖREN                                   9                   619
# 2      AKŞEHİR                                  12                  1754
# 3    ALTINEKİN                                  10                  1407
# 4     BEYŞEHİR                                  23                  2207
# 5       BOZKIR                                  17                  1518
# 6   CİHANBEYLİ                                   8                   510
# 7       ÇELTİK                                   4                   176
# 8        ÇUMRA                                  10                  1486
# 9      DERBENT                                   6                   490
# 10   DEREBUCAK                                   5                   505
# 11  DOĞANHİSAR                                  12                  1831
# ...

# %%
data.drop(columns="s.no", inplace=True)

# %%
data.drop(index=31, inplace=True)

# %%
data["2015_egitim_verilen_mahalle_sayisi"] = data["2015_egitim_verilen_mahalle_sayisi"].astype(int)

# %%
data["2015_egitim_verilen_mahalle_sayisi"]
# Out:
# 0     10
# 1      9
# 2     12
# 3     10
# 4     23
# 5     17
# 6      8
# 7      4
# 8     10
# 9      6
# 10     5
# 11    12
# 12     4
# 13    13
# 14    11
# 15    16
# 16     6
# 17    16
# 18    16
# 19     8
# 20     9
# 21     5
# 22     3
# 23    28
# 24    11
# 25     9
# 26    13
# 27     8
# 28     2
# 29     3
# 30     7
# Name: 2015_egitim_verilen_mahalle_sayisi, dtype: int64

# %%
for i in range(0,31):
    data["2015_kursiyer_sayisi"] = data["2015_kursiyer_sayisi"].astype(str)
    if data["2015_kursiyer_sayisi"][i].endswith(".0"):
        data["2015_kursiyer_sayisi"][i] = data["2015_kursiyer_sayisi"][i][:-2]
        data["2015_kursiyer_sayisi"][i] = int(data["2015_kursiyer_sayisi"][i])
    else:
        data["2015_kursiyer_sayisi"][i] = data["2015_kursiyer_sayisi"][i].replace(".","")
        data["2015_kursiyer_sayisi"][i] = int(data["2015_kursiyer_sayisi"][i])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/912907967.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2015_kursiyer_sayisi"][i] = data["2015_kursiyer_sayisi"][i][:-2]
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/912907967.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2015_kursiyer_sayisi"][i] = int(data["2015_kursiyer_sayisi"][i])
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/912907967.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data["2015_kursiyer_sayisi"][17] = int(data["2015_kursiyer_sayisi"][17])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/918562389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2015_kursiyer_sayisi"][17] = int(data["2015_kursiyer_sayisi"][17])

# %%
data["2015_kursiyer_sayisi"]
# Out:
# 0      973
# 1      619
# 2     1754
# 3     1407
# 4     2207
# 5     1518
# 6      510
# 7      176
# 8     1486
# 9      490
# 10     505
# 11    1831
# 12     783
# 13    1051
# 14    1086
# 15    1319
# 16     985
# 17      16
# 18    1491
# 19     245
# 20     771
# 21     320
# 22      65
# 23    1872
# 24     692
# 25     470
# 26    1845
# 27     774
# 28     110
# 29     159
# 30     385
# Name: 2015_kursiyer_sayisi, dtype: object

# %%
type(data["2016_kursiyer_sayisi"][10])
# Out:
# numpy.float64

# %%
data["2016_kursiyer_sayisi"]
# Out:
# 0     629.000
# 1     621.000
# 2       1.709
# 3     380.000
# 4       2.226
# 5       1.005
# 6       1.426
# 7     671.000
# 8       1.493
# 9     834.000
# 10      1.022
# 11      1.438
# 12    743.000
# 13    938.000
# 14    825.000
# 15    704.000
# 16    272.000
# 17      1.775
# 18      1.827
# 19      1.084
# 20      1.018
# 21      1.097
# 22    898.000
# 23      2.007
# 24      1.482
# 25      1.717
# 26      1.586
# 27    553.000
# 28    754.000
# 29    282.000
# 30    876.000
# Name: 2016_kursiyer_sayisi, dtype: float64

# %%
for i in range(0,31):
    data["2016_kursiyer_sayisi"] = data["2016_kursiyer_sayisi"].astype(str)
    if data["2016_kursiyer_sayisi"][i].endswith(".0"):
        data["2016_kursiyer_sayisi"][i] = data["2016_kursiyer_sayisi"][i][:-2]
        data["2016_kursiyer_sayisi"][i] = int(data["2016_kursiyer_sayisi"][i])
    else:
        data["2016_kursiyer_sayisi"][i] = data["2016_kursiyer_sayisi"][i].replace(".","")
        data["2016_kursiyer_sayisi"][i] = int(data["2016_kursiyer_sayisi"][i])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/309051891.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2016_kursiyer_sayisi"][i] = data["2016_kursiyer_sayisi"][i][:-2]
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/309051891.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2016_kursiyer_sayisi"][i] = int(data["2016_kursiyer_sayisi"][i])
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/309051891.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data["2016_kursiyer_sayisi"]
# Out:
# 0      629
# 1      621
# 2     1709
# 3      380
# 4     2226
# 5     1005
# 6     1426
# 7      671
# 8     1493
# 9      834
# 10    1022
# 11    1438
# 12     743
# 13     938
# 14     825
# 15     704
# 16     272
# 17    1775
# 18    1827
# 19    1084
# 20    1018
# 21    1097
# 22     898
# 23    2007
# 24    1482
# 25    1717
# 26    1586
# 27     553
# 28     754
# 29     282
# 30     876
# Name: 2016_kursiyer_sayisi, dtype: object

# %%
for i in range(0,31):
    data["2017_kursiyer_sayisi"] = data["2017_kursiyer_sayisi"].astype(str)
    if data["2017_kursiyer_sayisi"][i].endswith(".0"):
        data["2017_kursiyer_sayisi"][i] = data["2017_kursiyer_sayisi"][i][:-2]
        data["2017_kursiyer_sayisi"][i] = int(data["2017_kursiyer_sayisi"][i])
    else:
        data["2017_kursiyer_sayisi"][i] = data["2017_kursiyer_sayisi"][i].replace(".","")
        data["2017_kursiyer_sayisi"][i] = int(data["2017_kursiyer_sayisi"][i])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/3282687052.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2017_kursiyer_sayisi"][i] = data["2017_kursiyer_sayisi"][i][:-2]
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/3282687052.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2017_kursiyer_sayisi"][i] = int(data["2017_kursiyer_sayisi"][i])
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/3282687052.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(0,31):
    data["2018_kursiyer_sayisi"] = data["2018_kursiyer_sayisi"].astype(str)
    if data["2018_kursiyer_sayisi"][i].endswith(".0"):
        data["2018_kursiyer_sayisi"][i] = data["2018_kursiyer_sayisi"][i][:-2]
        data["2018_kursiyer_sayisi"][i] = int(data["2018_kursiyer_sayisi"][i])
    else:
        data["2018_kursiyer_sayisi"][i] = data["2018_kursiyer_sayisi"][i].replace(".","")
        data["2018_kursiyer_sayisi"][i] = int(data["2018_kursiyer_sayisi"][i])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/1561433377.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2018_kursiyer_sayisi"][i] = data["2018_kursiyer_sayisi"][i][:-2]
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/1561433377.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2018_kursiyer_sayisi"][i] = int(data["2018_kursiyer_sayisi"][i])
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/1561433377.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(0,31):
    data["2019_kursiyer_sayisi"] = data["2019_kursiyer_sayisi"].astype(str)
    if data["2019_kursiyer_sayisi"][i].endswith(".0"):
        data["2019_kursiyer_sayisi"][i] = data["2019_kursiyer_sayisi"][i][:-2]
        data["2019_kursiyer_sayisi"][i] = int(data["2019_kursiyer_sayisi"][i])
    else:
        data["2019_kursiyer_sayisi"][i] = data["2019_kursiyer_sayisi"][i].replace(".","")
        data["2019_kursiyer_sayisi"][i] = int(data["2019_kursiyer_sayisi"][i])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2205540426.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2019_kursiyer_sayisi"][i] = data["2019_kursiyer_sayisi"][i][:-2]
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2205540426.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2019_kursiyer_sayisi"][i] = int(data["2019_kursiyer_sayisi"][i])
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2205540426.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(0,31):
    data["2020_kursiyer_sayisi"] = data["2020_kursiyer_sayisi"].astype(str)
    if data["2020_kursiyer_sayisi"][i].endswith(".0"):
        data["2020_kursiyer_sayisi"][i] = data["2020_kursiyer_sayisi"][i][:-2]
        data["2020_kursiyer_sayisi"][i] = int(data["2020_kursiyer_sayisi"][i])
    else:
        data["2020_kursiyer_sayisi"][i] = data["2020_kursiyer_sayisi"][i].replace(".","")
        data["2020_kursiyer_sayisi"][i] = int(data["2020_kursiyer_sayisi"][i])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2239451100.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2020_kursiyer_sayisi"][i] = data["2020_kursiyer_sayisi"][i][:-2]
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2239451100.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2020_kursiyer_sayisi"][i] = int(data["2020_kursiyer_sayisi"][i])
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2239451100.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(0,31):
    data["2021_kursiyer_sayisi"] = data["2021_kursiyer_sayisi"].astype(str)
    if data["2021_kursiyer_sayisi"][i].endswith(".0"):
        data["2021_kursiyer_sayisi"][i] = data["2021_kursiyer_sayisi"][i][:-2]
        data["2021_kursiyer_sayisi"][i] = int(data["2021_kursiyer_sayisi"][i])
    else:
        data["2021_kursiyer_sayisi"][i] = data["2021_kursiyer_sayisi"][i].replace(".","")
        data["2021_kursiyer_sayisi"][i] = int(data["2021_kursiyer_sayisi"][i])
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2425622698.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2021_kursiyer_sayisi"][i] = data["2021_kursiyer_sayisi"][i][:-2]
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/2425622698.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["2021_kursiyer_sayisi"][i] = int(data["2021_kursiyer_sayisi"][i])

# %%
data["toplam_kursiyer_sayisi"] = data["toplam_kursiyer_sayisi"].astype(str).str.replace(".","")
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/4012617381.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["toplam_kursiyer_sayisi"] = data["toplam_kursiyer_sayisi"].astype(str).str.replace(".","")

# %%
data["toplam_kursiyer_sayisi"][29] = 707
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_42048/4051837775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["toplam_kursiyer_sayisi"][29] = 707

# %%
data["toplam_kursiyer_sayisi"] = data["toplam_kursiyer_sayisi"].astype(int)
data["toplam_egitim_verilen_mahalle_sayisi"] = data["toplam_egitim_verilen_mahalle_sayisi"].astype(int)

# %%
data["2016_egitim_verilen_mahalle_sayisi"] = data["2016_egitim_verilen_mahalle_sayisi"].astype(int)
data["2017_egitim_verilen_mahalle_sayisi"] = data["2017_egitim_verilen_mahalle_sayisi"].astype(int)
data["2018_egitim_verilen_mahalle_sayisi"] = data["2018_egitim_verilen_mahalle_sayisi"].astype(int)
data["2019_egitim_verilen_mahalle_sayisi"] = data["2019_egitim_verilen_mahalle_sayisi"].astype(int)
data["2020_egitim_verilen_mahalle_sayisi"] = data["2020_egitim_verilen_mahalle_sayisi"].astype(int)
data["2021_egitim_verilen_mahalle_sayisi"] = data["2021_egitim_verilen_mahalle_sayisi"].astype(int)

# %%
data["2021_egitim_verilen_mahalle_sayisi"]
# Out:
# 0      3
# 1      6
# 2     12
# 3      0
# 4     14
# 5     20
# 6      4
# 7      1
# 8     16
# 9      2
# 10     1
# 11     9
# 12     3
# 13     9
# 14     4
# 15     6
# 16     3
# 17    11
# 18     6
# 19     8
# 20     4
# 21    11
# 22     7
# 23    26
# 24     7
# 25     7
# 26    16
# 27     1
# 28     2
# 29     3
# 30     5
# Name: 2021_egitim_verilen_mahalle_sayisi, dtype: int64

# %%
data
# Out:
#         ilcesi  2015_egitim_verilen_mahalle_sayisi 2015_kursiyer_sayisi  \
# 0       AHIRLI                                  10                  973
# 1       AKÖREN                                   9                  619
# 2      AKŞEHİR                                  12                 1754
# 3    ALTINEKİN                                  10                 1407
# 4     BEYŞEHİR                                  23                 2207
# 5       BOZKIR                                  17                 1518
# 6   CİHANBEYLİ                                   8                  510
# 7       ÇELTİK                                   4                  176
# 8        ÇUMRA                                  10                 1486
# 9      DERBENT                                   6                  490
# 10   DEREBUCAK                                   5                  505
# 11  DOĞANHİSAR                                  12                 1831
# ...

# %%
data["2021_kursiyer_sayisi"] = data["2021_kursiyer_sayisi"].astype(int)
data["2020_kursiyer_sayisi"] = data["2020_kursiyer_sayisi"].astype(int)
data["2019_kursiyer_sayisi"] = data["2019_kursiyer_sayisi"].astype(int)
data["2018_kursiyer_sayisi"] = data["2018_kursiyer_sayisi"].astype(int)
data["2017_kursiyer_sayisi"] = data["2017_kursiyer_sayisi"].astype(int)
data["2016_kursiyer_sayisi"] = data["2016_kursiyer_sayisi"].astype(int)
data["2015_kursiyer_sayisi"] = data["2015_kursiyer_sayisi"].astype(int)

# %%
data["2016_kursiyer_sayisi"]
# Out:
# 0      629
# 1      621
# 2     1709
# 3      380
# 4     2226
# 5     1005
# 6     1426
# 7      671
# 8     1493
# 9      834
# 10    1022
# 11    1438
# 12     743
# 13     938
# 14     825
# 15     704
# 16     272
# 17    1775
# 18    1827
# 19    1084
# 20    1018
# 21    1097
# 22     898
# 23    2007
# 24    1482
# 25    1717
# 26    1586
# 27     553
# 28     754
# 29     282
# 30     876
# Name: 2016_kursiyer_sayisi, dtype: int64

# %%
data.to_csv("/Users/o/Desktop/acik-veri-calismalari/ciftci-egitim-envanteri/yillara-gore-ilcelerde-egitim-verilen-ciftci-sayilari.csv", index=False, header=True)
data.to_excel("/Users/o/Desktop/acik-veri-calismalari/ciftci-egitim-envanteri/yillara-gore-ilcelerde-egitim-verilen-ciftci-sayilari.xlsx", index=False, header=True)
