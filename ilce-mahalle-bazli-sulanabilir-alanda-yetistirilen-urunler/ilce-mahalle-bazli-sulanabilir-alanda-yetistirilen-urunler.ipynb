# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("ilce-mahalle-bazli-sulanabilir-alanda-yetistirilen-urunler-veri.csv")

# %%
pd.options.display.max_rows = None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 4 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   _id                                      773 non-null    int64
#  1   ilce_adi                                 772 non-null    object
#  2   mahalle_adi                              772 non-null    object
#  3   sulanabilir_alanda_yetistirilen_urunler  770 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 24.3+ KB

# %%
data.tail()
# Out:
#      _id ilce_adi mahalle_adi        sulanabilir_alanda_yetistirilen_urunler
# 768  769    Yunak    YEŞİLOBA         ŞEKER PANCARI, MISIR, FASULYE, DOMATES
# 769  770    Yunak  YEŞİLYAYLA                                        FASULYE
# 770  771    Yunak       YIĞAR                                MISIR, AYÇİÇEĞİ
# 771  772    Yunak       SARAY  ŞEKER PANCARI, MISIR, DOMATES, BİBER, PATATES
# 772  773      NaN         NaN                                            NaN

# %%
data.drop(columns="_id", inplace=True)

# %%
data.drop(index=772, inplace=True)

# %%
data.drop(index=676, inplace=True)
data.drop(index=644, inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head(100)
# Out:
#      ilce_adi  mahalle_adi            sulanabilir_alanda_yetistirilen_urunler  \
# 0      Ahırlı     ALİÇERÇİ                                                YOK
# 1      Ahırlı      BADEMLİ                                                YOK
# 2      Ahırlı    BALIKLAVA                    ELMA, KİRAZ, VİŞNE, ÇİLEK, ERİK
# 3      Ahırlı      BÜYÜKÖZ                                       BUĞDAY, ARPA
# 4      Ahırlı      ÇİFTLİK                                            FASULYE
# 5      Ahırlı      ERDOĞAN  ELMA, KİRAZ, ÜZÜM, DOMATES, BİBER, PATLICAN, P...
# 6      Ahırlı   KARACAKUYU                 BUĞDAY, DOMATES, PATLICAN, PATATES
# 7      Ahırlı      KAYACIK                               MISIR, ELMA, FASULYE
# 8      Ahırlı      KURUÇAY                                   DOMATES, PATATES
# 9      Ahırlı      KÜÇÜKÖZ                                         ELMA, ERİK
# 10     Akören        AVDAN           DOMATES, BİBER, PATLICAN, PATATES, SOĞAN
# ...

# %%
data["veri_sayisi"] = data["sulanabilir_alanda_yetistirilen_urunler"].str.count(",") + 1

# %%
data["veri_sayisi"].max()
# Out:
# 10

# %%
data[["sulanabilir_alanda_yetistirilen_urunler1", "sulanabilir_alanda_yetistirilen_urunler2", "sulanabilir_alanda_yetistirilen_urunler3", "sulanabilir_alanda_yetistirilen_urunler4", "sulanabilir_alanda_yetistirilen_urunler5", "sulanabilir_alanda_yetistirilen_urunler6", "sulanabilir_alanda_yetistirilen_urunler7", "sulanabilir_alanda_yetistirilen_urunler8", "sulanabilir_alanda_yetistirilen_urunler9", "sulanabilir_alanda_yetistirilen_urunler10"]] = data["sulanabilir_alanda_yetistirilen_urunler"].astype(str).str.split(",", expand=True)

# %%
data.drop(columns="sulanabilir_alanda_yetistirilen_urunler", inplace=True)

# %%
data.drop(columns="veri_sayisi", inplace=True)

# %%
for index, row in data.iterrows():
    for col in data.columns:
        if pd.isnull(row[col]):
            data.loc[index, col] = "YOK"

# %%
data
# Out:
#        ilce_adi       mahalle_adi sulanabilir_alanda_yetistirilen_urunler1  \
# 0        Ahırlı          ALİÇERÇİ                                      YOK
# 1        Ahırlı           BADEMLİ                                      YOK
# 2        Ahırlı         BALIKLAVA                                     ELMA
# 3        Ahırlı           BÜYÜKÖZ                                   BUĞDAY
# 4        Ahırlı           ÇİFTLİK                                  FASULYE
# 5        Ahırlı           ERDOĞAN                                     ELMA
# 6        Ahırlı        KARACAKUYU                                   BUĞDAY
# 7        Ahırlı           KAYACIK                                    MISIR
# 8        Ahırlı           KURUÇAY                                  DOMATES
# 9        Ahırlı           KÜÇÜKÖZ                                     ELMA
# 10       Akören             AVDAN                                  DOMATES
# ...

# %%
data.to_csv("/Users/o/Desktop/acik-veri-calismalari/ilce-mahalle-bazli-sulanabilir-alanda-yetistirilen-urunler/ilce-mahalle-bazli-sulanabilir-alanda-yetistirilen-urunler.csv", index=False, header=True)
data.to_excel("/Users/o/Desktop/acik-veri-calismalari/ilce-mahalle-bazli-sulanabilir-alanda-yetistirilen-urunler/ilce-mahalle-bazli-sulanabilir-alanda-yetistirilen-urunler.xlsx", index=False, header=True)
