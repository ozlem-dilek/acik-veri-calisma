# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("bilimmerkezi-ziyaretci-sayilari-veri.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ay_yil                      74 non-null     object
#  1   randevulu_ziyaretci_sayisi  74 non-null     int64
#  2   serbest_ziyaretci_sayisi    74 non-null     int64
#  3   toplam_ziyaretci_sayisi     74 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.4+ KB

# %%
pd.options.display.max_rows = None

# %%
data.rename(columns={"ay_yil" : "baslangic_tarihi"}, inplace=True)

# %%
data["bitis_tarihi"] = data["baslangic_tarihi"].copy()

# %%
yeni_sutunlar = ["baslangic_tarihi","bitis_tarihi", "randevulu_ziyaretci_sayisi", "serbest_ziyaretci_sayisi", "toplam_ziyaretci_sayisi",  ]

# %%
data = data[yeni_sutunlar]

# %%
for index in range(0,74):
    if data["bitis_tarihi"][index][5:7] == "01":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "03":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "04":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "05":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "06":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "07":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "08":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "09":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "10":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "11":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "30"
    elif data["bitis_tarihi"][index][5:7] == "12":
        data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
    elif data["bitis_tarihi"][index][5:7] == "02":
        if data["bitis_tarihi"][index][:4] == "2015":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2016":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
        elif data["bitis_tarihi"][index][:4] == "2017":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2018":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2019":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
        elif data["bitis_tarihi"][index][:4] == "2020":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "29"
        elif data["bitis_tarihi"][index][:4] == "2021":
            data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# Out:
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_48387/10137877.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "28"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_48387/10137877.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["bitis_tarihi"][index] = data["bitis_tarihi"][index][:8] + "31"
# /var/folders/jh/d35s6brj6td3270jfy770tjc0000gn/T/ipykernel_48387/10137877.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data["baslangic_tarihi"] = pd.to_datetime(data["baslangic_tarihi"], format = "%Y-%m-%d")

# %%
data["bitis_tarihi"] = pd.to_datetime(data["bitis_tarihi"], format = "%Y-%m-%d")

# %%
type(data["baslangic_tarihi"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(data["bitis_tarihi"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data
# Out:
#    baslangic_tarihi bitis_tarihi  randevulu_ziyaretci_sayisi  \
# 0        2015-01-01   2015-01-31                        1624
# 1        2015-02-01   2015-02-28                        2692
# 2        2015-03-01   2015-03-31                        9575
# 3        2015-04-01   2015-04-30                       12221
# 4        2015-05-01   2015-05-31                       12291
# 5        2015-06-01   2015-06-30                        4716
# 6        2015-07-01   2015-07-31                        4483
# 7        2015-08-01   2015-08-31                        4986
# 8        2015-09-01   2015-09-30                        1084
# 9        2015-10-01   2015-10-31                        5303
# 10       2015-11-01   2015-11-30                        6952
# 11       2015-12-01   2015-12-31                        7218
# 12       2016-01-01   2016-01-31                        5244
# 13       2016-02-01   2016-02-29                        3522
# ...

# %%
data.to_csv("/Users/o/Desktop/acik-veri-calismalari/bilim-merkezi-ziyaretci-sayilari/bilim-merkezi-ziyaretci-sayilari.csv", index=False, header=True)
data.to_excel("/Users/o/Desktop/acik-veri-calismalari/bilim-merkezi-ziyaretci-sayilari/bilim-merkezi-ziyaretci-sayilari.xlsx", index=False, header=True)
